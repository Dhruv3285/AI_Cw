# %%
# %matplotlib inline
import os
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

#reading file and using as dataframe
path = "."
filename_read = os.path.join(path, "skyserverv2.csv")
df = pd.read_csv(filename_read)

# 'objid' and 'rerun' are all the same values, hence not useful 
df.drop('objid',1,inplace=True) 
df.drop('rerun',1,inplace=True)
# Out:
# <ipython-input-107-119bb66ced3a>:15: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop('objid',1,inplace=True)
# <ipython-input-107-119bb66ced3a>:16: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop('rerun',1,inplace=True)
# <AxesSubplot:>

# %%
# split dataset
X = data.iloc[:, 0:16]
y = data.iloc[:, 16]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size= 0.2)


gnb = GaussianNB()
gnb.fit(X_train, y_train)

y_pred = gnb.predict(X_test)
print(f"total number of instances: {X_test.shape[0]} Incorrect Guesses: {(y_test != y_pred).sum()}")

rate = (y_test != y_pred).sum() / X_test.shape[0]
print(f"Accuracy: {1 - rate}")
